# %%
from cleaner import cleaner
from solver import solver

# %%
letters = 'racdhin'
letters = cleaner(letters)

# %%
solutions = solver(letters)
len(solutions)
# Out:
# 303

# %%
solutions
# Out:
# ['acara',
#  'acarari',
#  'acardia',
#  'acardiac',
#  'acari',
#  'acarian',
#  'acarid',
#  'acarida',
#  'acaridan',
#  'acarina',
#  'accra',
#  'achar',
#  'achira',
#  'acinar',
#  'acrania',
#  'acrid',
#  'acridan',
#  'acridian',
#  'acridic',
#  'acridid',
#  'acridin',
#  'acridinic',
#  'adar',
#  'addr',
#  'adhara',
#  'adrad',
#  'adrian',
#  'adriana',
#  'ahir',
#  'aira',
#  'airan',
#  'airn',
#  'anacara',
#  'anacard',
#  'anacardic',
#  'anandria',
#  'anarch',
#  'anarchic',
#  'andhra',
#  'andira',
#  'andirin',
#  'andria',
#  'andriana',
#  'andric',
#  'aniridia',
#  'annard',
#  'araca',
#  'aracana',
#  'aracari',
#  'arach',
#  'arachic',
#  'arachidic',
#  'arachin',
#  'arachnid',
#  'arachnida',
#  'arachnidan',
#  'arad',
#  'aradid',
#  'arain',
#  'arar',
#  'arara',
#  'arca',
#  'arcadia',
#  'arcadian',
#  'arcadic',
#  'arcana',
#  'arch',
#  'archai',
#  'archaic',
#  'archd',
#  'archin',
#  'ardhanari',
#  'ardri',
#  'arhar',
#  'aria',
# ...
